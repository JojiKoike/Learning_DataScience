# %%
import numpy as np
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set()
# %matplotlib inline

# %precision 3
# Out:
# '%.3f'

# %%
pwd
# Out:
# '/Users/george/WorkSpace/study/datascience/datasciencetraining/chapter3'

# %%
import requests, zipfile
from io import StringIO
import io

url =  'http://archive.ics.uci.edu/ml/machine-learning-databases/00356/student.zip'
r = requests.get(url, stream=True)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

# %%
# Load CSV Data into Pandas Data Frame
student_data_math = pd.read_csv('student-mat.csv', sep=';')
student_data_math
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
student_data_math.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
student_data_math['sex'].head()
# Out:
# 0    F
# 1    F
# 2    F
# 3    F
# 4    F
# Name: sex, dtype: object

# %%
student_data_math['absences'].head()
# Out:
# 0     6
# 1     4
# 2    10
# 3     2
# 4     4
# Name: absences, dtype: int64

# %%
student_data_math.groupby('sex')['age'].mean()
# Out:
# sex
# F    16.730769
# M    16.657754
# Name: age, dtype: float64

# %%
# HIstogram
plt.hist(student_data_math['absences'])
plt.xlabel('absences')
plt.ylabel('count')
plt.grid(True)

# %%
# Average, Median, Mode
print("Average : {0}".format(student_data_math['absences'].mean()))
print("Median : {0}".format(student_data_math['absences'].median()))
print("Mode : {0}".format(student_data_math['absences'].mode()))
# Out:
# Average : 5.708860759493671
# Median : 4.0
# Mode : 0    0
# dtype: int64

# %%
# Deviation, Std. Deviation
print("Variant : {0}".format(student_data_math['absences'].var()))
print("Std. : {0}".format(student_data_math['absences'].std()))
# Out:
# Variant : 64.04954057700957
# Std. : 8.00309568710818

# %%
# Statics Overview
student_data_math['absences'].describe()
# Out:
# count    395.000000
# mean       5.708861
# std        8.003096
# min        0.000000
# 25%        0.000000
# 50%        4.000000
# 75%        8.000000
# max       75.000000
# Name: absences, dtype: float64

# %%
# Summarized Statics
student_data_math.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
# Boxplot
plt.boxplot(student_data_math['G1'])
plt.grid(True)

# %%
plt.boxplot(student_data_math['absences'])
plt.grid(True)

# %%
plt.boxplot(student_data_math['freetime'])
plt.grid(True)

# %%
plt.boxplot([student_data_math['G1'], student_data_math['G2'], student_data_math['G3']])
plt.grid(True)

# %%
# Variant Coefficient
student_data_math['absences'].std() / student_data_math['absences'].mean()
# Out:
# 1.4018726369879073

# %%
student_data_math.std() / student_data_math.mean()
# Out:
# age           0.076427
# Medu          0.398177
# Fedu          0.431565
# traveltime    0.481668
# studytime     0.412313
# failures      2.225319
# famrel        0.227330
# freetime      0.308725
# goout         0.358098
# Dalc          0.601441
# Walc          0.562121
# health        0.391147
# absences      1.401873
# G1            0.304266
# G2            0.351086
# G3            0.439881
# dtype: float64

# %%
# Scatter Plot
plt.plot(student_data_math['G1'], student_data_math['G3'], 'o')
plt.ylabel('G3 grade')
plt.xlabel('G1 grade')
plt.grid(True)

# %%
# Co-variant matrix
np.cov(student_data_math['G1'], student_data_math['G3'])
# Out:
# array([[11.017, 12.188],
#        [12.188, 20.99 ]])

# %%
# Variant
print("Variant G1: {0}".format(student_data_math['G1'].var()))
print("Variant G3: {0}".format(student_data_math['G3'].var()))
# Out:
# Variant G1: 11.017053267364904
# Variant G3: 20.989616397866733

# %%
# Pearson Relation Coefficient
sp.stats.pearsonr(student_data_math['G1'], student_data_math['G3'])
# Out:
# (0.8014679320174141, 9.001430312277354e-90)

# %%
np.corrcoef([student_data_math['G1'], student_data_math['G3']])
# Out:
# array([[1.   , 0.801],
#        [0.801, 1.   ]])

# %%
sns.pairplot(student_data_math[['Dalc', 'Walc', 'G1', 'G3']])
plt.grid(True)
